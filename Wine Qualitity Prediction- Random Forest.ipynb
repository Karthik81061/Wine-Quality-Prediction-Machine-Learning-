# %%
#F:\MachineLearningProjects\winequality-red.csv

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('F:\MachineLearningProjects\winequality-red.csv')

# %%
data.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
data.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
data.shape
# Out:
# (1599, 12)

# %% [markdown]
# ### Data Analysis andd visualization

# %%
data.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
# num of values for each qulaty
sns.catplot(x='quality',data=data,kind='count')

# %%
# Volatile acidity and Quality

sns.barplot(x='quality',y= 'volatile acidity',data = data)
plt.show()

# %%
# Volatile acidity and Quality
sns.barplot(x='quality',y= 'citric acid',data = data)
plt.show()

# %%
# Residual sugar and Quality
sns.barplot(x='quality',y= 'alcohol',data = data)
plt.show()

# %%
# Find Correlation
plt.figure(figsize=(10,10))
sns.heatmap(data=data.corr(),annot=True, cbar=True,square=True,fmt = '.1f',annot_kws={'size':8} )
plt.show()

# %% [markdown]
# ### Data PrePreocessing

# %%
# Seperation
X1 = data.drop(columns ='quality',axis=1,)

# %%
X.shape
# Out:
# (1599, 11)

# %%
# Label Binerazation setting threshold
y = data['quality'].apply(lambda y_value:1 if y_value>=7 else 0)

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1594    0
# 1595    0
# 1596    0
# 1597    0
# 1598    0
# Name: quality, Length: 1599, dtype: int64

# %% [markdown]
# ### Spliting xtt and ytt

# %%
xtrain,xtest,ytrain,ytest = train_test_split(X,y,test_size=0.2,random_state=1)

# %% [markdown]
# ### Random Forest (ensmble)

# %%
model1 = RandomForestClassifier()

# %%
model1.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier()

# %%
trainpred1= model1.predict(xtrain)

# %%
accuracy_score(ytrain,trainpred1)
# Out:
# 1.0

# %%
testpred1 = model.predict(xtest)

# %%
accuracy_score(ytest,testpred1)
# Out:
# 0.921875
